# %% [markdown]
# # Data Analysis on Open Source 1921 Census Data - MakerSpace Taster Session, School of Advanced Studies

# %% [markdown]
# ### This notebook is a simple walk through of some functions that can be used to analyse a subset of data from the 1921 Census of England and Wales.

# %% [markdown]
# ###  The data has been downloaded from the UK Data Service under Creative Commons (CC).

# %% [markdown]
# The following workbook demonstrates some of the basic data analysis that can be done using Pandas dataframes.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# When you have downloaded the data file you will need to insert the file path in the field below where it says 'enter file path'.
# After this cell is run the original data file will be refered to as **df** in the code.

# %%
df = pd.read_csv('/Users/janeskelding/Documents/1921/Digital Humanities training and sandpit/Census data/Wanstead1921.csv')

# %% [markdown]
# The first few cells just demonstrate some simple functions that give basic information about the data file. .sample() shows a selection of rows from the data so we can see that the file is working. We can limit the number of rows in the brackets at the end.

# %%
df.sample(5)
# Out:
#        CenYear     recid      hid  pid  ParID  ConParID Country  RegCnty  \
# 15871     1921  12012489  2895139    4   3104      3074     ENG   ESSEX
# 33434     1921  12019855  2896922    3   3104      3074     ENG   ESSEX
# 35270     1921  12017143  2896237    6   3104      3074     ENG   ESSEX
# 4938      1921  11975371  2886203    4   3103      3074     ENG   ESSEX
# 10578     1921  11976366  2886484    3   3103      3074     ENG   ESSEX
#
#       AdminCnty     RegDist  ... wheredelivered  wherecollected  ShipsMaster  \
# 15871    ESSEX    WEST HAM   ...             -               -            -
# 33434    ESSEX    WEST HAM   ...             -               -            -
# 35270    ESSEX    WEST HAM   ...             -               -            -
# 4938     ESSEX    WEST HAM   ...             -               -            -
# 10578    ESSEX    WEST HAM   ...             -               -            -
#
#        VessMooring Rank  ServiceBranch Service nameshipbarracks  \
# 15871           -    -              -       -                -
# 33434           -    -              -       -                -
# 35270           -    -              -       -                -
# 4938            -    -              -       -                -
# 10578           -    -              -       -                -
#
#       typeshipbarracks locshipbarracks
# 15871               -                -
# 33434               -                -
# 35270               -                -
# 4938                -                -
# 10578               -                -
#
# [5 rows x 120 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36283 entries, 0 to 36282
# Columns: 120 entries, CenYear to locshipbarracks
# dtypes: float64(2), int64(57), object(61)
# memory usage: 33.2+ MB

# %%
df.nunique()
# Out:
# CenYear                 1
# recid               36283
# hid                  8872
# pid                   337
# ParID                   2
#                     ...
# ServiceBranch           1
# Service                 1
# nameshipbarracks        1
# typeshipbarracks        1
# locshipbarracks         1
# Length: 120, dtype: int64

# %%
df.sort_values(by=['recid'])
# Out:
#        CenYear     recid      hid  pid  ParID  ConParID Country  RegCnty  \
# 26679     1921  11968544  2884574    1   3103      3074     ENG   ESSEX
# 25966     1921  11968545  2884574    2   3103      3074     ENG   ESSEX
# 11224     1921  11968546  2884574    3   3103      3074     ENG   ESSEX
# 23137     1921  11968547  2884574    4   3103      3074     ENG   ESSEX
# 14621     1921  11968548  2884575    1   3103      3074     ENG   ESSEX
# ...        ...       ...      ...  ...    ...       ...     ...      ...
# 11563     1921  12033070  2900268    1   3104      3074     ENG   ESSEX
# 17821     1921  12033071  2900268    2   3104      3074     ENG   ESSEX
# 10861     1921  12033072  2900268    3   3104      3074     ENG   ESSEX
# 22754     1921  12033073  2900269    1   3104      3074     ENG   ESSEX
# 30528     1921  12033074  2900269    2   3104      3074     ENG   ESSEX
#
#       AdminCnty     RegDist  ... wheredelivered  wherecollected  ShipsMaster  \
# 26679    ESSEX    WEST HAM   ...             -               -            -
# 25966    ESSEX    WEST HAM   ...             -               -            -
# 11224    ESSEX    WEST HAM   ...             -               -            -
# 23137    ESSEX    WEST HAM   ...             -               -            -
# 14621    ESSEX    WEST HAM   ...             -               -            -
# ...         ...         ...  ...            ...             ...          ...
# 11563    ESSEX    WEST HAM   ...             -               -            -
# 17821    ESSEX    WEST HAM   ...             -               -            -
# 10861    ESSEX    WEST HAM   ...             -               -            -
# 22754    ESSEX    WEST HAM   ...             -               -            -
# 30528    ESSEX    WEST HAM   ...             -               -            -
#
#        VessMooring Rank  ServiceBranch Service nameshipbarracks  \
# 26679           -    -              -       -                -
# 25966           -    -              -       -                -
# 11224           -    -              -       -                -
# 23137           -    -              -       -                -
# 14621           -    -              -       -                -
# ...            ...  ...            ...     ...              ...
# 11563           -    -              -       -                -
# 17821           -    -              -       -                -
# 10861           -    -              -       -                -
# 22754           -    -              -       -                -
# 30528           -    -              -       -                -
#
#       typeshipbarracks locshipbarracks
# 26679               -                -
# 25966               -                -
# 11224               -                -
# 23137               -                -
# 14621               -                -
# ...                ...             ...
# 11563               -                -
# 17821               -                -
# 10861               -                -
# 22754               -                -
# 30528               -                -
#
# [36283 rows x 120 columns]

# %% [markdown]
# The dataset has 120 columns which is too large to see easily in the dataframe and also contains many columns that are not of interest. The function below lists them all so that we can decide which ones we want to display.

# %%
df.columns.values.tolist()
# Out:
# ['CenYear',
#  'recid',
#  'hid',
#  'pid',
#  'ParID',
#  'ConParID',
#  'Country',
#  'RegCnty',
#  'AdminCnty',
#  'RegDist',
#  'SubDist',
#  'RD',
#  'RSD',
#  'Cen_Num',
#  'Parish',
#  'EnuDist',
#  'Schedule',
#  'LatLong',
#  'Censusref',
#  'imageREF',
#  'DocType',
#  'BuildType',
#  'BTCode',
#  'NoOfRooms',
#  'Noofroomscode',
#  'Sex',
#  'Age',
#  'Cage',
#  'Intage',
#  'Cond',
#  'Mar',
#  'Relat',
#  'Rela',
#  'Flag',
#  'Orphan',
#  'Education',
#  'Educode',
#  'Occ',
#  'Occode',
#  'HollerOcc',
#  'HollerNos',
#  'Employ',
#  'HISCO',
#  'Industry',
#  'HollerInd',
#  'HollerStat',
#  'EmployCode',
#  'Employer',
#  'EmployerCode',
#  'PlaceOfWork',
#  'PoWStat',
#  'PoW1',
#  'PoW2',
#  'AtHome',
#  'Inactive',
#  'Bpstring',
#  'BpID',
#  'BpCtry',
#  'BpCNTRY',
#  'BpCnty',
#  'BpCNTI',
#  'BpCmty',
#  'StanPlace',
#  'BP_EW',
#  'BP_NS',
#  'Distance',
#  'HollerBP',
#  'Nationality',
#  'disab',
#  'discode1',
#  'discode2',
#  'Lang',
#  'langcode',
#  'YearsMar',
#  'MarYear',
#  'ChildTot',
#  'ChildAlive',
#  'ChildDead',
#  'ChildrenCode',
#  'Children',
#  'HHD',
#  'Household',
#  'TotalPersons',
#  'H_Sex',
#  'H_Age',
#  'H_Mar',
#  'H_Occ',
#  'H_CFU',
#  'CFU',
#  'CFUsize',
#  'Spouse',
#  'Father',
#  'Mother',
#  'NM_Offsp',
#  'EM_Offsp',
#  'Relats',
#  'Inmates',
#  'Servts',
#  'Non_Rels',
#  'Visitors',
#  'InstName',
#  'InstDesc',
#  'InstCode',
#  'VessName',
#  'VessNum',
#  'VessPos',
#  'PassengerOrCrew',
#  'SeaFishery',
#  'Port',
#  'VessDesc',
#  'wheredelivered',
#  'wherecollected',
#  'ShipsMaster',
#  'VessMooring',
#  'Rank',
#  'ServiceBranch',
#  'Service',
#  'nameshipbarracks',
#  'typeshipbarracks',
#  'locshipbarracks']

# %% [markdown]
# The next cell is ammending the dataframe to select just the columns we want to work with today.

# %%
df=df[['Parish','imageREF','Cond','Relat','Sex','Age','Occ','Occode','Employer','EmployerCode','Bpstring','BpCmty','InstName','LatLong','recid','hid']]

# %%
df.sort_values(by=['recid'])
# Out:
#             Parish                       imageREF       Cond          Relat  \
# 26679    WANSTEAD    GBC/1921/RG15/08549/0005/01    MARRIED           HEAD
# 25966    WANSTEAD    GBC/1921/RG15/08549/0005/02    MARRIED           WIFE
# 11224    WANSTEAD    GBC/1921/RG15/08549/0005/03     SINGLE            SON
# 23137    WANSTEAD    GBC/1921/RG15/08549/0005/04     SINGLE        SERVANT
# 14621    WANSTEAD    GBC/1921/RG15/08549/0007/01    MARRIED           HEAD
# ...            ...                            ...        ...            ...
# 11563   CANN HALL    GBC/1921/RG15/08585/0905/01    MARRIED           HEAD
# 17821   CANN HALL    GBC/1921/RG15/08585/0905/02    MARRIED           WIFE
# 10861   CANN HALL    GBC/1921/RG15/08585/0905/03          -       DAUGHTER
# 22754   CANN HALL    GBC/1921/RG15/08585/0907/01    WIDOWED           HEAD
# 30528   CANN HALL    GBC/1921/RG15/08585/0907/02     SINGLE    HOUSEKEEPER
#
#       Sex  Age                                      Occ  Occode  \
# 26679   M   66                     TOBACCO MANUFCAETRS      706
# 25966   F   54                                       -   999999
# 11224   M   42                  MEMBER OF LONDON STOAN      122
# 23137   F   27                GENERAL DOMESTIC SERVANT       84
# 14621   M   44               ROAD TRANSPORT CONTRACTOR      141
# ...    ..  ...                                      ...     ...
# 11563   M   27   ENGINEER TURNER, REPAIR OF LOCOMOTIVE      272
# 17821   F   22                             HOME DUTIES      788
# 10861   F    1                                       -   999999
# 22754   M   57                      TIME & GATE KEEPER      761
# 30528   F   50                            HOUSE KEEPER       84
#
#                             Employer  EmployerCode  \
# 26679                             -         999999
# 25966                             -         999999
# 11224                             -         999999
# 23137                       PRIVATE          88888
# 14621                      EMPLOYER          88888
# ...                              ...           ...
# 11563      MIDLAND RAILWAY, COMPANY            623
# 17821                             -         999999
# 10861                             -         999999
# 22754   EXCEL CO LTD FOOD PRESEVERS         999999
# 30528                FREDERICK NOEL         999999
#
#                             Bpstring          BpCmty InstName  \
# 26679             MIDDLESEX, LONDON          LONDON        -
# 25966   NORTHAMPTON, WELLINGBOROUGH     NORTHAMPTON        -
# 11224             MIDDLESEX, LONDON          LONDON        -
# 23137                KENT, WOOLWICH        WOOLWICH        -
# 14621              ESSEX, SILVERTON      SILVERTOWN        -
# ...                              ...             ...      ...
# 11563              SUFFOLK, LEISTON         LEISTON        -
# 17821           ESSEX, CUSTOM HOUSE    CUSTOM HOUSE        -
# 10861           ESSEX, CUSTOM HOUSE    CUSTOM HOUSE        -
# 22754            LEYTONSTONE, ESSEX     LEYTONSTONE        -
# 30528              BRENTWOOD, ESSEX       BRENTWOOD        -
#
#                    LatLong     recid      hid
# 26679      51.5879,0.0216   11968544  2884574
# 25966      51.5879,0.0216   11968545  2884574
# 11224      51.5879,0.0216   11968546  2884574
# 23137      51.5879,0.0216   11968547  2884574
# 14621   51.5858,0.0208676   11968548  2884575
# ...                    ...       ...      ...
# 11563      51.5593,0.0115   12033070  2900268
# 17821      51.5593,0.0115   12033071  2900268
# 10861      51.5593,0.0115   12033072  2900268
# 22754      51.5593,0.0115   12033073  2900269
# 30528      51.5593,0.0115   12033074  2900269
#
# [36283 rows x 16 columns]

# %%
df.nunique()
# Out:
# Parish              2
# imageREF        36283
# Cond                6
# Relat             202
# Sex                 3
# Age                97
# Occ              8570
# Occode            468
# Employer        11124
# EmployerCode      268
# Bpstring         9184
# BpCmty           2130
# InstName            9
# LatLong           180
# recid           36283
# hid              8872
# dtype: int64

# %%
df['Relat'].value_counts()[:10]
# Out:
# Relat
# HEAD         8425
# DAUGHTER     7761
# SON          7186
# WIFE         6854
# SERVANT       819
# BOARDER       755
# VISITOR       705
# INMATE        595
# SISTER        326
# MOTHER        265
# Name: count, dtype: int64

# %% [markdown]
# # Simple charts

# %%
df['Sex'].value_counts()[:10].plot(kind='bar', title='Gender of Census respondents')
# Out:
# <Axes: title={'center': 'Gender of Census respondents'}, xlabel='Sex'>

# %%
df['Relat'].value_counts()[:10].plot(kind='bar', title='Type of Census respondents by Relationship')
# Out:
# <Axes: title={'center': 'Type of Census respondents by Relationship'}, xlabel='Relat'>

# %%
df['Relat'].value_counts()[:10].plot(kind='pie', title='Relationship choices of Census respondents')
# Out:
# <Axes: title={'center': 'Relationship choices of Census respondents'}, ylabel='count'>

# %%
df['Relat'].value_counts()[:10].plot(kind='barh', title='Relationship choices of Census respondents')
# Out:
# <Axes: title={'center': 'Relationship choices of Census respondents'}, ylabel='Relat'>

# %% [markdown]
# To save any of the output charts for use in essays or papers, we can use the following code

# %%
chart = df['Relat'].value_counts()[:10].plot(kind='barh', title='Relationship choices of Census respondents')
chart.figure.savefig('Relationships1921chart.pdf')

# %% [markdown]
# # Basic filters

# %%
women_filter = df['Sex']=='F'

# %%
census_women = df[women_filter]

# %%
census_women.head()[:10]
# Out:
#         Parish                       imageREF       Cond      Relat Sex  Age  \
# 0    WANSTEAD    GBC/1921/RG15/08557/0945/02    MARRIED       WIFE    F   38
# 1    WANSTEAD    GBC/1921/RG15/08558/0005/10    WIDOWED    OFFICER    F   32
# 2    WANSTEAD    GBC/1921/RG15/08558/0010/10          -     INMATE    F   13
# 3    WANSTEAD    GBC/1921/RG15/08558/0011/08          -     INMATE    F    7
# 14   WANSTEAD    GBC/1921/RG15/08558/0040/15          -     INMATE    F   14
#
#                       Occ  Occode                       Employer  \
# 0            HOME DUTIES      788                             -
# 1    CHILDRENS ATTENDANT      109   WEST HAM BOARD OF GUARDIANS
# 2                      -   999999                             -
# 3                      -   999999                             -
# 14                     -   999999                             -
#
#     EmployerCode                         Bpstring          BpCmty  \
# 0         999999            MIDDLESEX, ISLINGTON       ISLINGTON
# 1            998   NORTHAMPTONSHIRE, NORTHAMPTON     NORTHAMPTON
# 2         999999             ESSEX, CANNING TOWN    CANNING TOWN
# 3         999999             ESSEX, CANNING TOWN    CANNING TOWN
# 14        999999             YORKSHIRE, BARNSLEY        BARNSLEY
#
#                                              InstName              LatLong  \
# 0                                                  -       51.5635,0.0375
# 1    WEST HAM UNION CHILDREN'S HOUSES  ALDERSBROOK...   51.5631,0.0298798
# 2    WEST HAM UNION CHILDREN'S HOUSES  ALDERSBROOK...   51.5631,0.0298798
# 3    WEST HAM UNION CHILDREN'S HOUSES  ALDERSBROOK...   51.5631,0.0298798
# 14   ROYAL INFANT ORPHANAGE  WOODFORD ROAD  WANSTEAD       51.5879,0.0216
#
#        recid      hid
# 0   11983239  2888214
# 1   11983301  2888228
# 2   11983371  2888228
# 3   11983384  2888228
# 14  11983738  2888229

# %%
census_women.nunique()
# Out:
# Parish              2
# imageREF        19653
# Cond                6
# Relat             154
# Sex                 1
# Age                96
# Occ              2264
# Occode            241
# Employer         3359
# EmployerCode      132
# Bpstring         5959
# BpCmty           1556
# InstName            9
# LatLong           180
# recid           19653
# hid              8656
# dtype: int64

# %%
census_women['Relat'].value_counts()
# Out:
# Relat
# DAUGHTER                  7739
# WIFE                      6849
# HEAD                      1150
# SERVANT                    800
# VISITOR                    479
#                           ...
# CHILD NURSE                  1
# SUB-TENANT                   1
# NEPHEW'S DAUGHTER            1
# WIFE, DAUGHTER-IN-LAW        1
# GREAT AUNT                   1
# Name: count, Length: 154, dtype: int64

# %%
men_filter = df['Sex']=='M'

# %%
census_men = df[men_filter]

# %%
census_men['Relat'].value_counts()
# Out:
# Relat
# HEAD                  7270
# SON                   7153
# BOARDER                426
# INMATE                 324
# VISITOR                226
#                       ...
# BOARDER, HUSBAND         1
# TEMPORARY BOARDER        1
# LODGER'S SON             1
# VISITOR, COUSIN          1
# STEP-FATHER              1
# Name: count, Length: 94, dtype: int64

# %%
age_filter = df['Age']>=14

# %%
df[age_filter]
# Out:
#            Parish                       imageREF       Cond       Relat Sex  \
# 0       WANSTEAD    GBC/1921/RG15/08557/0945/02    MARRIED        WIFE    F
# 1       WANSTEAD    GBC/1921/RG15/08558/0005/10    WIDOWED     OFFICER    F
# 6       WANSTEAD    GBC/1921/RG15/08558/0017/15          -      INMATE    M
# 7       WANSTEAD    GBC/1921/RG15/08558/0019/07          -      INMATE    M
# 14      WANSTEAD    GBC/1921/RG15/08558/0040/15          -      INMATE    F
# ...           ...                            ...        ...         ...  ..
# 36277   WANSTEAD    GBC/1921/RG15/08557/0095/02    MARRIED        WIFE    F
# 36279   WANSTEAD    GBC/1921/RG15/08557/0159/04     SINGLE     VISITOR    F
# 36280   WANSTEAD    GBC/1921/RG15/08557/0169/03     SINGLE    DAUGHTER    F
# 36281   WANSTEAD    GBC/1921/RG15/08557/0175/02    MARRIED        WIFE    F
# 36282   WANSTEAD    GBC/1921/RG15/08557/0179/01    MARRIED        HEAD    M
#
#        Age                    Occ  Occode  \
# 0       38           HOME DUTIES      788
# 1       32   CHILDRENS ATTENDANT      109
# 6       15                     -   999999
# 7       14                     -   999999
# 14      14                     -   999999
# ...    ...                    ...     ...
# 36277   44      HOUSEHOLD DUTIES      788
# 36279   52          PHOTOGRAPHER       75
# 36280   15                     -   999999
# 36281   40      HOUSEHOLD DUTIES      788
# 36282   47       MARINE ENGINEER      158
#
#                                     Employer  EmployerCode  \
# 0                                         -         999999
# 1               WEST HAM BOARD OF GUARDIANS            998
# 6                                         -         999999
# 7                                         -         999999
# 14                                        -         999999
# ...                                      ...           ...
# 36277                                     -         999999
# 36279                           OWN ACCOUNT          88888
# 36280                                     -         999999
# 36281                                     -         999999
# 36282   MESSERS PRINCE LINC LTD SHIP OWNERS         999999
#
#                               Bpstring          BpCmty  \
# 0                MIDDLESEX, ISLINGTON       ISLINGTON
# 1       NORTHAMPTONSHIRE, NORTHAMPTON     NORTHAMPTON
# 6                   ESSEX, WALHAMSTON               -
# 7                        NEAR IRELAND               -
# 14                YORKSHIRE, BARNSLEY        BARNSLEY
# ...                                ...             ...
# 36277                  ESSEX, BARKING         BARKING
# 36279           SUFFOLK, GREAT BARTON    GREAT BARTON
# 36280                  ESSEX, EASTHAM        EAST HAM
# 36281                     NEW ZEALAND               -
# 36282                 HULL, YORKSHIRE            HULL
#
#                                                 InstName              LatLong  \
# 0                                                     -       51.5635,0.0375
# 1       WEST HAM UNION CHILDREN'S HOUSES  ALDERSBROOK...   51.5631,0.0298798
# 6       WEST HAM UNION CHILDREN'S HOUSES  ALDERSBROOK...   51.5631,0.0298798
# 7       WEST HAM UNION CHILDREN'S HOUSES  ALDERSBROOK...   51.5631,0.0298798
# 14      ROYAL INFANT ORPHANAGE  WOODFORD ROAD  WANSTEAD       51.5879,0.0216
# ...                                                  ...                  ...
# 36277                                                 -       51.5635,0.0375
# 36279                                                 -        51.5635,0.042
# 36280                                                 -        51.5635,0.042
# 36281                                                 -        51.5635,0.042
# 36282                                                 -        51.5635,0.042
#
#           recid      hid
# 0      11983239  2888214
# 1      11983301  2888228
# 6      11983481  2888228
# 7      11983503  2888228
# 14     11983738  2888229
# ...         ...      ...
# 36277  11981621  2887790
# 36279  11981751  2887821
# 36280  11981771  2887826
# 36281  11981780  2887829
# 36282  11981789  2887831
#
# [27490 rows x 16 columns]

# %% [markdown]
# If you want to export any of the filtered datasets there is a simple way to output a dataframe to .csv.

# %%
census_women.to_csv("1921censuswomen.csv", encoding='utf-8', index=False)
